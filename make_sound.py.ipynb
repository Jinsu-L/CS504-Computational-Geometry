# %%
import scipy
import numpy as np
from IPython.display import Audio, display

# %%
duration = 10
frequency = 432
sampling_rate=44100

t = np.linspace(0, duration, int(sampling_rate) * duration)
# y = np.sin(4 * np.pi * t) * np.sin(2 * np.pi * frequency * t)
y = np.sin(2 * np.pi * frequency * t)

# %%
display(Audio(y, rate=44100))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
duration = 5
frequency = 110
form_to = np.linspace(0, frequency, int(sampling_rate) * duration)
sampling_rate=44100

t = np.linspace(0, duration, int(sampling_rate) * duration)
y = np.sin(0.4 * np.pi * t)* np.sin(2 * np.pi * form_to * t)

# %%
display(Audio(y, rate=44100))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
np.sin(2 * np.pi * t)
# Out:
# array([ 0.00000000e+00,  1.42476180e-04,  2.84952357e-04, ...,
#        -2.84952357e-04, -1.42476180e-04, -2.44929360e-15])
